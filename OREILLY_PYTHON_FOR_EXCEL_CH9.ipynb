# %%
# Create a DataFrame based on pseudorandom numbers and with enough rows that only the head and tail are shown

import datetime as dt
import xlwings as xw
import pandas as pd
import numpy as np

df = pd.DataFrame(data=np.random.randn(100, 5),
                  columns=[f"Trial {i}" for i in range(1, 6)])
df
# Out:
#      Trial 1   Trial 2   Trial 3   Trial 4   Trial 5
# 0   0.219390  1.020893  0.338427  0.750334 -0.036261
# 1   0.567573  0.073362 -1.665043 -0.853860  0.046211
# 2   0.118868  1.803852 -0.564330  0.628400  1.120682
# 3   0.381261 -1.284958  1.566684 -1.299950 -0.907069
# 4   0.214677 -0.591628 -1.923461  1.791890  0.339579
# ..       ...       ...       ...       ...       ...
# 95 -1.726355  1.261003  0.966005 -0.088088 -0.607872
# 96  0.933637  0.218003  1.339104 -0.402238  0.744205
# 97  0.063450 -0.180357 -0.082031 -0.762983  0.214467
# 98 -1.478936  0.147751 -0.760737  0.519073 -0.093416
# 99  0.817385  0.336171 -1.113814 -0.095500 -0.284201
#
# [100 rows x 5 columns]

# %%
# In [3]: # View the DataFrame in Excel

xw.view(df)
