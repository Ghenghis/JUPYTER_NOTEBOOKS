# %%
# In [1]: # First, let's import the packages that we'll use in this chapter

import datetime as dt
import xlwings as xw
import pandas as pd
import numpy as np

# %%
# In [2]: # Let's create a DataFrame based on pseudorandom numbers and
        # with enough rows that only the head and tail are shown

df = pd.DataFrame(data=np.random.randn(100, 5),
                  columns=[f"Trial {i}" for i in range(1, 6)])
df
# Out:
#      Trial 1   Trial 2   Trial 3   Trial 4   Trial 5
# 0   0.995911 -0.670976  0.625035  0.582845 -0.865471
# 1   1.642300  0.862293  1.225522  0.272076  0.270926
# 2   0.649007 -0.568830  1.475199 -0.694024 -1.255615
# 3  -0.000077 -0.432005  0.310281  1.874196 -0.400612
# 4  -0.461791 -0.572440  0.457531 -0.747894  0.534480
# ..       ...       ...       ...       ...       ...
# 95  0.913491 -0.136690 -0.615505 -1.267001  1.205342
# 96  0.172513 -0.664821  0.760689  0.280933  0.051082
# 97  1.078740 -1.116023  0.852505 -1.661120 -0.947444
# 98 -1.672842  0.217903  0.769256 -1.151618 -2.271573
# 99  1.228533  1.200333  1.411506 -1.572330  0.350996
#
# [100 rows x 5 columns]

# %%
# In [3]: # View the DataFrame in Excel

xw.view(df)
