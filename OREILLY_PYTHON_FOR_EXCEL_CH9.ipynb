# %%
# Create a DataFrame based on pseudorandom numbers and with enough rows that only the head and tail are shown

import datetime as dt
import xlwings as xw
import pandas as pd
import numpy as np

df = pd.DataFrame(data=np.random.randn(100, 5),
                  columns=[f"Trial {i}" for i in range(1, 6)])

# View the DataFrame in Excel
xw.view(df)

df
# Out:
#      Trial 1   Trial 2   Trial 3   Trial 4   Trial 5
# 0  -1.819079  1.005092  0.462424  0.731612 -0.205463
# 1  -0.897825 -1.118005 -1.595991  0.306325  0.164323
# 2  -0.729758 -1.488814  0.523203  0.868609 -1.035442
# 3   0.666738  0.671024  1.573564 -1.487488 -1.365680
# 4  -1.644643 -0.040092  0.240521  0.528498  1.956847
# ..       ...       ...       ...       ...       ...
# 95  0.222806 -1.102880  0.735812  0.514779 -0.908524
# 96 -0.098394 -1.257713 -0.148419  0.516701  0.553987
# 97  2.114082 -0.368802  0.430166  1.029491 -0.767578
# 98 -2.231987 -0.583610 -0.430659 -0.205751  0.228956
# 99 -0.320287 -1.574427  1.798212  0.648178  0.205126
#
# [100 rows x 5 columns]
