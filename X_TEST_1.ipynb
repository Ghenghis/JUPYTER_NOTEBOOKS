# %%
# Python decorators example ###

var1 = 'foo'

def identity(var1):
    return var1

print(identity(var1))

@identity
def foo():
    return 'bar'

print(foo())
# Out:
# foo
# bar

# %%
##### Write a function that returns the larger of two numbers #####

def get_larger_number(n1, n2):
    if n1 > n2:
        return f"{n1} is larger than {n2}\n"
    elif n2 > n1:
        return f"{n2} is larger than {n1}\n"
    else:
        return f"{n1} is equal to {n2}\n"

while True:
    try:
        n1 = float(input("Enter the first number: "))
        n2 = float(input("Enter the second number: "))
    except ValueError:
        print("INPUT ERROR:  Please enter two numbers instead\n")
    else:
        print("YOUR INPUT ACCEPTED")
        print(get_larger_number(n1, n2))
        break
# Out:
# YOUR INPUT ACCEPTED
# 33.0 is larger than 22.0

# %%
import numpy as np

a = np.arange(12)

# a
# type(a)
a.shape = 3, 4
# a[2]
# Out:
# array([ 8,  9, 10, 11])

# %%
##### FROM P. 124 OF PYTHON FOR DATA ANALYSIS #####

obj = pd.Series([4, 7, -5, 3])
obj

# obj.array
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
##### FROM P. 367 OF PYTHON FOR DATA ANALYSIS #####

index = pd.date_range("2012-04-01", "2012-06-01")
index

##### FROM P. 368 OF BOOK:  PYTHON FOR DATA ANALYSIS #####
# import pandas as pd

# pd.date_range(start="2012-04-01", periods=20)
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Years for which we have battery sales data
x = [2011, 2012, 2013, 2014, 2015]
# Repeat X, 5 times to represent each of the 5 battery ratings
X = x * 5
# List of Battery ratings
battery_ratings = ['7Ah', '35Ah', '40Ah', '135Ah', '150Ah']
# Number of units sold each year, each rating. e.g. 75 units of 7Ah(0) batteries, 144 units of 35Ah(1) #     batteries sold in 2011
Y = np.array([[75, 144, 114, 102, 108],
              [90, 126, 102, 84, 126],
              [96, 114, 75, 105, 135],
              [105, 90, 175, 90, 75],
              [90, 75, 135, 75, 90]])
# Represent batery rating in numeric codes
yticks = [0, 1, 2, 3, 4]
# Use different color for each of the battery ratings
colors = ['r', 'g', 'b', 'y', 'm']

i=0
for c, k in zip(colors, yticks):
    cs = [c] * len(x)
    ax.bar(X[i:i+5], Y[:,int(i/5)], zs=k, zdir='y', color=cs, alpha=0.8)
    i += 5

ax.set_yticks(yticks)
ax.set_yticklabels(battery_ratings)
ax.set_xlabel('Year')
ax.set_ylabel('Battery Type')
ax.set_zlabel('Units Sold')

plt.show()

# %%
##### FROM P. 97 OF PYTHON TRICKS:  THE BOOK (DEFAULT RETURN VALUES) #####

def foo1(value):
    if value:
        return value
    else:
        return None
  
def foo2(value):
    if value:
        return value
    else:
        return
    
def foo3(value):
    if value:
        return value

print(foo1(1), foo1(2), foo1(3))
# print(foo2(2))
# print(foo3(3))
# Out:
# 1 2 3

# %%
count = 2
fruit = "Pear"

print(f"{count = }")
print(f"{fruit = }")
# Out:
# count = 2
# fruit = 'Pear'

# %%
#### Write a function that returns the larger of two numbers #####

def get_larger_number(n1, n2):
    if n1 > n2:
        return f"\n{n1} is larger than {n2}\n"
    elif n2 > n1:
        return f"\n{n2} is larger than {n1}\n"
    else:
        return f"\n{n1} and {n2} are equal\n"

first_no = input("Enter first number: ")
second_no = input("Enter second number: ")

print(get_larger_number(first_no, second_no))
# Out:
# 999 is larger than 888

# %%
##### Write a function that returns the result of a calculation involving two numbers #####

n1 = input("\nEnter first number: ")
n2 = input("Enter second number: ")

n1float = float(n1)
n2float = float(n2)

def get_product(n1float, n2float):
    return n1float * n2float

product = get_product(n1float, n2float)

print(f"RESULT OF " '{:,.2f}'.format(n1float), "X",'{:,.2f}'.format(n2float), "=", '{:,.2f}'.format(product), "\n")
# Out:
# RESULT OF 1.00 X 124.00 = 124.00

# %%
#### DECORATOR EXAMPLES FROM P. 78 OF PYTHON TRICKS #####

def uppercase(func):
    def wrapper():
        original_result = func()
        modified_result = original_result.upper()
        return modified_result
    return wrapper

def lowercase(func):
    def wrapper():
        original_result = func()
        modified_result = original_result.lower()
        return modified_result
    return wrapper

@uppercase
def greet1():
    return '\nthis sentence was originally all in lowercase text; it was converted to uppercase by using the @uppercase decorator'

@lowercase
def greet2():
    return 'THIS SENTENCE WAS ORIGINALLY ALL IN UPPERCASE TEXT; IT WAS CONVERTED TO LOWERCASE BY USING THE @LOWERCASE DECORATOR\n'

print(greet1())
print(greet2())
# Out:
# THIS SENTENCE WAS ORIGINALLY ALL IN LOWERCASE TEXT; IT WAS CONVERTED TO UPPERCASE BY USING THE @UPPERCASE DECORATOR
# this sentence was originally all in uppercase text; it was converted to lowercase by using the @lowercase decorator

# %%
##### DECORATOR EXAMPLE FROM P. 81 OF PYTHON TRICKS #####

def strong(func):
    def wrapper():
        return '<strong>' + func() + '</strong>'
    return wrapper

def emphasis(func):
    def wrapper():
        return '<em>' + func() + '</em>'
    return wrapper

@strong
@emphasis
def greet():
    return 'Hello!'

print(greet())
# Out:
# <strong><em>Hello!</em></strong>

# %%
##### EXAMPLE OF *args AND **kwargs FROM P. 88 OF PYTHON TRICKS:  THE BOOK #####

def foo(required, *args, **kwargs):
    print(required)
    if args:
        print(args)
    if kwargs:
        print(kwargs)

foo('hello')
foo('hello', 1, 2, 3)
foo('hello', 1, 2, 3, key1='value', key2=999)
# Out:
# hello
# hello
# (1, 2, 3)
# hello
# (1, 2, 3)
# {'key1': 'value', 'key2': 999}

# %%
## TYPE HINT EXAMPLES FROM MICROSOFT COPILOT ###

# def greeting(name: str) -> str:
#     return 'Hello ' + name

# print(greeting('John'))

#####

def add_numbers(int1: int, int2: int) -> int:
    return int1 + int2

int1 = int(input("Enter integer 1 "))
int2 = int(input("Enter integer 2 "))

add_numbers(int1, int2)
# Out:
# 55
