# %% [markdown]
# This is an example of text included in a **markdown** cell included in a **Jupyter Notebook** (*.ipynb file).  You can review the Python code and the resulting output (graph) below.  Thanks.

# %%
from matplotlib import pyplot as plt

plt.plot([1, 2, 30, 4, 5])
plt.plot([1, 20, 4, 8, 16])
plt.plot([1, 10, 100, 100, 100])
plt.show()
